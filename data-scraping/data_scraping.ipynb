# %% [markdown]
# notes:
# https://myxalandri.gr/sitemap.xml

# %%
from bs4 import BeautifulSoup
import requests
import re
import json
import os
import shutil
import zipfile

# %% [markdown]
# ### Create diretories

# %%
urls = []
site_maps_file = 'sitemaps.txt'

# choice to delete or not delete the existing directories
delete_existing_directories = False


# Check if the file exists
if os.path.exists(site_maps_file):
    # Read the file and save each URL from each line to a list
    with open(site_maps_file, 'r') as f:
        urls = f.readlines()
else:
    # Warn that the file does not exist
    print('File does not exist')


for url in urls:
    # Extract the domain name and top-level domain (TLD) from the URL
    domain_dot_tld = re.search(r'(?<=https://)(.*?)(?=/)', url).group(0)

    # Check if the directory exists (directory name contains the domain name and TLD)
    if not os.path.exists(domain_dot_tld):
        print(f'Creating new directory {domain_dot_tld}')
        os.makedirs(domain_dot_tld)
    elif delete_existing_directories:
        print(f'Directory {domain_dot_tld} already exists. Deleting it and creating a new one')
        # Delete the directory and create a new one
        shutil.rmtree(domain_dot_tld)
        os.makedirs(domain_dot_tld)
    else:
        print(f'Directory {domain_dot_tld} already exists')
    
    # create 3 directories under the domain_dot_tld directory: html_files, txt_files,  metadata_files
    html_files = os.path.join(domain_dot_tld, 'html_files')
    txt_files = os.path.join(domain_dot_tld, 'txt_files')
    metadata_files = os.path.join(domain_dot_tld, 'metadata_files')

    # Check if the directories exist
    if not os.path.exists(html_files):
        print(f'Creating new directory {html_files}')
        os.makedirs(html_files)
    else: 
        print(f'Directory {html_files} already exists')

    if not os.path.exists(txt_files):
        print(f'Creating new directory {txt_files}')
        os.makedirs(txt_files)
    else: 
        print(f'Directory {txt_files} already exists')

    if not os.path.exists(metadata_files):
        print(f'Creating new directory {metadata_files}')
        os.makedirs(metadata_files)
    else:
        print(f'Directory {metadata_files} already exists')
# Out:
# Creating new directory myxalandri.gr
# Creating new directory myxalandri.gr/html_files
# Creating new directory myxalandri.gr/txt_files
# Creating new directory myxalandri.gr/metadata_files

# %% [markdown]
# ### Filter out the index pages and extract the relevant information from the articles
# takes around 8-9 minutes to execute

# %%
def is_index_page(soup, tag):
    """
    Check if the URL is an index page.
    """

    # get all meta tags with name author
    meta_tags = soup.find_all('meta', attrs={'name': 'author'})
    if meta_tags:
        print(f'Website: {tag.text}')
        # print(meta_tags)
        print('--' * 80)
        return 0 # return 0 if it is not an index page
    else:
        print(f'Website: {tag.text}')
        print("This is an index page. No meta tags with name author")
        print('--' * 80)
        return 1 # return 1 if it is an index page


def extract_html(html_document, domain_dot_tld, idx_file):
    """
    Extract the HTML document from the URL
    """

    # Write the HTML document to a .html file
    with open(domain_dot_tld + "/html_files/" +  str(idx_file) + '.html', 'w') as f:
        f.write(html_document.text)
        f.close()    

# def extract_headline_and_description(soup, domain_dot_tld, idx_file):
#     """
#     Extract the headline and description from the JSON data
#     """
    
#     script_tags = soup.find_all('script', attrs={'data-type': 'gsd'})

#     # Extract the headline and description from each script tag
#     for script_tag in script_tags:
#         # Extract the JSON data
#         json_data = script_tag.string.strip()

#         # Parse the JSON data
#         data = json.loads(json_data)

#         # Extract the headline and description using the get() method
#         headline = data.get('headline')
#         description = data.get('description')

#         # Print the extracted values
#         if headline is not None and description is not None:
#             with open(domain_dot_tld + "/txt_files/" +  str(idx_file) + '.txt', 'w') as f:
#                 f.write('Title:'+ '\n' + headline + '\n')
#                 f.write('Description:' + '\n' + description + '\n')
#                 f.close()



### Alternative method to extract headline and description (doesn't work yet, and probably not optimal for this website) ### 
# def extract_headline_and_description(soup, domain_dot_tld, idx_file):
#     """
#     Extract the headline and description from the JSON data
#     """

    
#     h1_tags = soup.find_all('h1', class_='uk-article-title uk-margin-top-remove')
#     # extracted_h1_content = [tag.get_text() for tag in h1_tags]

#     # p_tags = soup.find_all('p')
#     p_tags = soup.find_all('span')
#     # extracted_p_content = [tag.find('span', style=re.compile(r'font-size: medium;')).get_text() for tag in p_tags]

#     for h1_tag in h1_tags:
#         print(h1_tag.get_text())

#     for p_tag in p_tags:
#         print(p_tag.get_text())
#         # print(p_tag)


def extract_metadata(soup, domain_dot_tld, idx_file):
    """
    Extract the metadata from the HTML document
    """

    # Find all <meta> tags
    meta_tags = soup.find_all('meta')

    # Extract the desired metadata from each meta tag
    metadata = {}
    for meta_tag in meta_tags:
        name = meta_tag.get('name')
        content = meta_tag.get('content')
        if name and content:
            metadata[name] = content

    # Write the metadata to a .meta file in JSON format
    meta_file = domain_dot_tld + "/metadata_files/" +  str(idx_file) + '.meta'
    with open(meta_file, 'w') as f:
        f.write(json.dumps(metadata, indent=4, ensure_ascii=False))

# %%
idx_article_page = 0
idx_index_page = 0

# Retrieve the sitemap.xml file
xml_document = requests.get(xml[1])
# Parse the XML document
soup = BeautifulSoup(xml_document.text, 'html.parser')
# Find all the <loc> tags
loc_tags = soup.find_all('loc')


# Loop over each tag and extract the data
for tag in loc_tags:
    # Retrieve the HTML document using the get() method of the requests module
    html_document = requests.get(tag.text)

    # Create a BeautifulSoup object for parsing the HTML document
    soup = BeautifulSoup(html_document.text, 'html.parser')

    # if url is front page, skip
    if tag.text.split('/')[-1] == '': 
        continue

    # if url is index page, skip
    if is_index_page(soup, tag):
        idx_index_page += 1
        continue
    
    # Extract the domain name and TLD from the URL
    domain_dot_tld = re.search(r'(?<=https://)(.*?)(?=/)', xml[1]).group(0)

    # Extracting phase
    extract_html(html_document, domain_dot_tld, idx_article_page)

    extract_headline_and_description(soup, domain_dot_tld, idx_article_page)

    extract_metadata(soup, domain_dot_tld, idx_article_page)

    idx_article_page += 1

# Show information about the files extracted
print('###' * 30)
print(f'Number of all pages: {idx_article_page + idx_index_page}')
print(f'Number of article pages: {idx_article_page}')
print(f'Number of index pages: {idx_index_page}')
print(f'Percentage of index pages: {round(idx_index_page/idx_article_page*100, 2)}%')
# Out:
# Website: https://myxalandri.gr/eidiseis
# This is an index page. No meta tags with name author
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Website: https://myxalandri.gr/athlitismos
# This is an index page. No meta tags with name author
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Website: https://myxalandri.gr/politismos
# This is an index page. No meta tags with name author
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Website: https://myxalandri.gr/apopseis
# This is an index page. No meta tags with name author
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Website: https://myxalandri.gr/out-xalandri
# This is an index page. No meta tags with name author
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Website: https://myxalandri.gr/mymag
# This is an index page. No meta tags with name author
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Website: https://myxalandri.gr/politismos/18694-to-neo-orario-kai-o-tropos-leitourgias-ton-dimotikon-vivliothikon-xalandriou
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#                                     Το νέο ωράριο και ο τρόπος λειτουργίας των Δημοτικών Βιβλιοθηκών Χαλανδρίου
# 09-09-20
# ΠΟΛΙΤΙΣΜΟΣ
# Οδηγίες για την ασφάλεια και την αποφυγή της εξάπλωσης του κορωνοϊού
# Οδηγίες για την ασφάλεια και την αποφυγή της εξάπλωσης του κορωνοϊού
# Ανοίγει η αυλαία του Φεστιβάλ Ρεματιάς 2023 “Νύχτες Αλληλεγγύης” – Το πρόγραμμα των εκδηλώσεων
# Εγκαίνια της έκθεσης “Rema Incognita” – Η Ρεματιά Χαλανδρίου μέσα από τα μάτια διακεκριμένων εικαστικών
# Συνομιλώντας με τον ζωγράφο Ορέστη Κύρτση στην Γκαλερί Χρυσόθεμις
# Η κωμωδία “Δεν είμαι εγώ ή Η Λογική” από τον Σύλλογο Χαλανδρίου ΑΡΓΩ, στο Θέατρο Ρεματιάς
# Ταυτότητα
# Όροι Χρήσης
# Διαφήμιση
# Ακολουθήστε μας!
# Website: https://myxalandri.gr/eidiseis/18688-kalosorisma-tis-enosis-goneon-xalandriou-gia-ti-nea-sxoliki-xronia
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#                                     Καλωσόρισμα της Ένωσης Γονέων Χαλανδρίου για τη νέα σχολική χρονιά
# 09-09-20
# ΕΙΔΗΣΕΙΣ
# Το καλωσόρισμα της Ένωσης Συλλόγων Γονέων Μαθητών Χαλανδρίου για τη νέα σχολική χρονιά:
# Βρέθηκε σώα η 56χρονη που είχε εξαφανιστεί από το Μαρούσι
# Ταυτοποιήθηκαν δύο άτομα που παραβίασαν με κατσαβίδι είσοδο πολυκατοικίας στο Χαλάνδρι
# Σοβαρό τροχαίο στο Χαλάνδρι: Αυτοκίνητο προσέκρουσε σε μεταλλική κολώνα (βίντεο)
# Χάρης Ρώμας: «Το πανέμορφο θέατρο Ρεματιάς Χαλανδρίου, δεν πρέπει επ’ ουδενί να διατίθεται για κομματικές ομιλίες και φιέστες»
# Ταυτότητα
# Όροι Χρήσης
# Διαφήμιση
# Ακολουθήστε μας!
# Website: https://myxalandri.gr/eidiseis/18691-me-156-687-88-epixorigeitai-o-dimos-xalandriou-gia-pliromi-misthomaton-sxolikon-monadon
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#                                     Με 156.687,88 € επιχορηγείται ο Δήμος Χαλανδρίου για πληρωμή μισθωμάτων σχολικών μονάδων
# 09-09-20
# ΕΙΔΗΣΕΙΣ
# Βρέθηκε σώα η 56χρονη που είχε εξαφανιστεί από το Μαρούσι
# Ταυτοποιήθηκαν δύο άτομα που παραβίασαν με κατσαβίδι είσοδο πολυκατοικίας στο Χαλάνδρι
# Σοβαρό τροχαίο στο Χαλάνδρι: Αυτοκίνητο προσέκρουσε σε μεταλλική κολώνα (βίντεο)
# Χάρης Ρώμας: «Το πανέμορφο θέατρο Ρεματιάς Χαλανδρίου, δεν πρέπει επ’ ουδενί να διατίθεται για κομματικές ομιλίες και φιέστες»
# Ταυτότητα
# Όροι Χρήσης
# Διαφήμιση
# Ακολουθήστε μας!
# Website: https://myxalandri.gr/eidiseis/18693-fotia-se-aporrimmatoforo-tou-dimou-xalandriou-pos-proklithike
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#                                     Φωτιά σε απορριμματοφόρο του Δήμου Χαλανδρίου - Πώς προκλήθηκε
# 09-09-20
# ΕΙΔΗΣΕΙΣ
# Βρέθηκε σώα η 56χρονη που είχε εξαφανιστεί από το Μαρούσι
# Ταυτοποιήθηκαν δύο άτομα που παραβίασαν με κατσαβίδι είσοδο πολυκατοικίας στο Χαλάνδρι
# Σοβαρό τροχαίο στο Χαλάνδρι: Αυτοκίνητο προσέκρουσε σε μεταλλική κολώνα (βίντεο)
# Χάρης Ρώμας: «Το πανέμορφο θέατρο Ρεματιάς Χαλανδρίου, δεν πρέπει επ’ ουδενί να διατίθεται για κομματικές ομιλίες και φιέστες»
# Ταυτότητα
# Όροι Χρήσης
# Διαφήμιση
# Ακολουθήστε μας!
# Website: https://myxalandri.gr/eidiseis/18690-synelifthi-sto-xalandri-50xronos-allodapos-gia-tilefonikes-apates-me-to-prosxima-troxaiou-atyximatos
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#                                     Συνελήφθη στο Χαλάνδρι 50χρονος αλλοδαπός για τηλεφωνικές απάτες με το πρόσχημα τροχαίου ατυχήματος
# 08-09-20
# ΕΙΔΗΣΕΙΣ
# Βρέθηκε σώα η 56χρονη που είχε εξαφανιστεί από το Μαρούσι
# Ταυτοποιήθηκαν δύο άτομα που παραβίασαν με κατσαβίδι είσοδο πολυκατοικίας στο Χαλάνδρι
# Σοβαρό τροχαίο στο Χαλάνδρι: Αυτοκίνητο προσέκρουσε σε μεταλλική κολώνα (βίντεο)
# Χάρης Ρώμας: «Το πανέμορφο θέατρο Ρεματιάς Χαλανδρίου, δεν πρέπει επ’ ουδενί να διατίθεται για κομματικές ομιλίες και φιέστες»
# Ταυτότητα
# Όροι Χρήσης
# Διαφήμιση
# Ακολουθήστε μας!
# Website: https://myxalandri.gr/athlitismos/18689-xalandri-orizontas-2023-o-athlitismos-exei-koinoniko-prosimo-kai-einai-to-xamogelo-kathe-topikis-koinonias
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#                                     “Χαλάνδρι Ορίζοντας 2023”: Ο αθλητισμός έχει κοινωνικό πρόσημο και είναι “το χαμόγελο” κάθε τοπικής κοινωνίας
# 08-09-20
# ΑΘΛΗΤΙΣΜΟΣ
# ΔΕΛΤΙΟ ΤΥΠΟΥ
# HALBIKE: Η Halαρή ποδηλατοβόλτα του Χαλανδρίου στις 19/7
# Το Χαλάνδρι πρωταθλητής στο 1ο Διαδημοτικό Τουρνουά Ποδοσφαίρου Παίδων
# Πρόκριση για την ομάδα ποδοσφαίρου του Δήμου Χαλανδρίου στο 1ο Διαδημοτικό Τουρνουά Ποδοσφαίρου Παίδων
# Πρωταθλητές ξανά οι “Underrated” στο 2ο πρωτάθλημα ποδοσφαίρου 5Χ5 των γυμνασίων του Χαλανδρίου
# Ταυτότητα
# Όροι Χρήσης
# Διαφήμιση
# Ακολουθήστε μας!
# Website: https://myxalandri.gr/eidiseis/18687-dimos-xalandriou-nea-sxoliki-xronia-se-kainoyrgia-sxoleia
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#                                     Α-Γ ΕΛΜΕ Β' Αθήνας: Ανοιχτό κάλεσμα σε γονείς και εκπαιδευτικούς για το άνοιγμα των σχολείων
# 07-09-20
# ΕΙΔΗΣΕΙΣ
# H πρόσκληση της Α-Γ ΕΛΜΕ Β' Αθήνας προς γονείς και εκπαιδευτικούς
# Βρέθηκε σώα η 56χρονη που είχε εξαφανιστεί από το Μαρούσι
# Ταυτοποιήθηκαν δύο άτομα που παραβίασαν με κατσαβίδι είσοδο πολυκατοικίας στο Χαλάνδρι
# Σοβαρό τροχαίο στο Χαλάνδρι: Αυτοκίνητο προσέκρουσε σε μεταλλική κολώνα (βίντεο)
# Χάρης Ρώμας: «Το πανέμορφο θέατρο Ρεματιάς Χαλανδρίου, δεν πρέπει επ’ ουδενί να διατίθεται για κομματικές ομιλίες και φιέστες»
# Ταυτότητα
# Όροι Χρήσης
# Διαφήμιση
# Ακολουθήστε μας!
# Website: https://myxalandri.gr/eidiseis/18684-2o-ergastirio-symmetoxikoy-sxediasmoy-gia-ti-sofokli-venizelou-sto-kato-xalandri
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#                                     2ο Εργαστήριο Συμμετοχικού Σχεδιασμού για τη Σοφοκλή Βενιζέλου στο Κάτω Χαλάνδρι
# 07-09-20
# ΕΙΔΗΣΕΙΣ
# Αυτή η διεύθυνση ηλεκτρονικού ταχυδρομείου προστατεύεται από τους αυτοματισμούς αποστολέων ανεπιθύμητων μηνυμάτων. Χρειάζεται να ενεργοποιήσετε τη JavaScript για να μπορέσετε να τη δείτε.
# Βρέθηκε σώα η 56χρονη που είχε εξαφανιστεί από το Μαρούσι
# Ταυτοποιήθηκαν δύο άτομα που παραβίασαν με κατσαβίδι είσοδο πολυκατοικίας στο Χαλάνδρι
# Σοβαρό τροχαίο στο Χαλάνδρι: Αυτοκίνητο προσέκρουσε σε μεταλλική κολώνα (βίντεο)
# Χάρης Ρώμας: «Το πανέμορφο θέατρο Ρεματιάς Χαλανδρίου, δεν πρέπει επ’ ουδενί να διατίθεται για κομματικές ομιλίες και φιέστες»
# Ταυτότητα
# Όροι Χρήσης
# Διαφήμιση
# Ακολουθήστε μας!
# Website: https://myxalandri.gr/athlitismos/18682-mono-me-rantevoy-i-eisodos-sto-athlitiko-kentro-n-perkizas-logo-koronoioy
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#                                     Μόνο με ραντεβού η είσοδος στο αθλητικό κέντρο “Ν. Πέρκιζας”, λόγω κορωνοϊού
# 07-09-20
# ΑΘΛΗΤΙΣΜΟΣ
# HALBIKE: Η Halαρή ποδηλατοβόλτα του Χαλανδρίου στις 19/7
# Το Χαλάνδρι πρωταθλητής στο 1ο Διαδημοτικό Τουρνουά Ποδοσφαίρου Παίδων
# Πρόκριση για την ομάδα ποδοσφαίρου του Δήμου Χαλανδρίου στο 1ο Διαδημοτικό Τουρνουά Ποδοσφαίρου Παίδων
# Πρωταθλητές ξανά οι “Underrated” στο 2ο πρωτάθλημα ποδοσφαίρου 5Χ5 των γυμνασίων του Χαλανδρίου
# Ταυτότητα
# Όροι Χρήσης
# Διαφήμιση
# Ακολουθήστε μας!
# Website: https://myxalandri.gr/athlitismos/18600-halbike-i-halari-podilatovolta-tou-xalandriou-stis-9-9
# This is an index page. No meta tags with name author
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Website: https://myxalandri.gr/athlitismos/18676-dimos-xalandriou-enarksi-dimotikon-athlitikon-programmaton
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#                                     Δήμος Χαλανδρίου: Έναρξη δημοτικών αθλητικών προγραμμάτων
# 04-09-20
# ΑΘΛΗΤΙΣΜΟΣ
# Αυτή η διεύθυνση ηλεκτρονικού ταχυδρομείου προστατεύεται από τους αυτοματισμούς αποστολέων ανεπιθύμητων μηνυμάτων. Χρειάζεται να ενεργοποιήσετε τη JavaScript για να μπορέσετε να τη δείτε.
# Αυτή η διεύθυνση ηλεκτρονικού ταχυδρομείου προστατεύεται από τους αυτοματισμούς αποστολέων ανεπιθύμητων μηνυμάτων. Χρειάζεται να ενεργοποιήσετε τη JavaScript για να μπορέσετε να τη δείτε.
# Αυτή η διεύθυνση ηλεκτρονικού ταχυδρομείου προστατεύεται από τους αυτοματισμούς αποστολέων ανεπιθύμητων μηνυμάτων. Χρειάζεται να ενεργοποιήσετε τη JavaScript για να μπορέσετε να τη δείτε.
# Αυτή η διεύθυνση ηλεκτρονικού ταχυδρομείου προστατεύεται από τους αυτοματισμούς αποστολέων ανεπιθύμητων μηνυμάτων. Χρειάζεται να ενεργοποιήσετε τη JavaScript για να μπορέσετε να τη δείτε.
# HALBIKE: Η Halαρή ποδηλατοβόλτα του Χαλανδρίου στις 19/7
# Το Χαλάνδρι πρωταθλητής στο 1ο Διαδημοτικό Τουρνουά Ποδοσφαίρου Παίδων
# Πρόκριση για την ομάδα ποδοσφαίρου του Δήμου Χαλανδρίου στο 1ο Διαδημοτικό Τουρνουά Ποδοσφαίρου Παίδων
# Πρωταθλητές ξανά οι “Underrated” στο 2ο πρωτάθλημα ποδοσφαίρου 5Χ5 των γυμνασίων του Χαλανδρίου
# Ταυτότητα
# Όροι Χρήσης
# Διαφήμιση
# Ακολουθήστε μας!
# Website: https://myxalandri.gr/athlitismos/18675-proponiseis-volei-enilikon-apo-ton-athlitiko-omilo-dioni
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#                                     Προπονήσεις βόλεϊ Ενηλίκων από τον Αθλητικό Όμιλο Διώνη
# 04-09-20
# ΑΘΛΗΤΙΣΜΟΣ
# Αυτή η διεύθυνση ηλεκτρονικού ταχυδρομείου προστατεύεται από τους αυτοματισμούς αποστολέων ανεπιθύμητων μηνυμάτων. Χρειάζεται να ενεργοποιήσετε τη JavaScript για να μπορέσετε να τη δείτε.
# HALBIKE: Η Halαρή ποδηλατοβόλτα του Χαλανδρίου στις 19/7
# Το Χαλάνδρι πρωταθλητής στο 1ο Διαδημοτικό Τουρνουά Ποδοσφαίρου Παίδων
# Πρόκριση για την ομάδα ποδοσφαίρου του Δήμου Χαλανδρίου στο 1ο Διαδημοτικό Τουρνουά Ποδοσφαίρου Παίδων
# Πρωταθλητές ξανά οι “Underrated” στο 2ο πρωτάθλημα ποδοσφαίρου 5Χ5 των γυμνασίων του Χαλανδρίου
# Ταυτότητα
# Όροι Χρήσης
# Διαφήμιση
# Ακολουθήστε μας!
# Website: https://myxalandri.gr/politismos/18672-i-fotografia-stin-plateia-ekthesi-fotografias-sto-xalandri
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#                                     “Η φωτογραφία στην Πλατεία”: Έκθεση φωτογραφίας στο Χαλάνδρι
# 03-09-20
# ΠΟΛΙΤΙΣΜΟΣ
# «Η φωτογραφία στην Πλατεία» - Έκθεση φωτογραφίας από τη Διεύθυνση Πολιτισμού και Αετοπούλειου Πολιτιστικού Κέντρου
# «Φωτογραφία Δρόμου & Δημιουργία Φωτο-Ιστορίας»
# Σημείωμα του εισηγητή Θανάση Σταυράκη
# «Ο λόγος στην Εικόνα» (Α’ & Β’ Κύκλος)
# Σημείωμα του εισηγητή Μπάμπη Κουγεμήτρου
# Ανοίγει η αυλαία του Φεστιβάλ Ρεματιάς 2023 “Νύχτες Αλληλεγγύης” – Το πρόγραμμα των εκδηλώσεων
# Εγκαίνια της έκθεσης “Rema Incognita” – Η Ρεματιά Χαλανδρίου μέσα από τα μάτια διακεκριμένων εικαστικών
# Συνομιλώντας με τον ζωγράφο Ορέστη Κύρτση στην Γκαλερί Χρυσόθεμις
# Η κωμωδία “Δεν είμαι εγώ ή Η Λογική” από τον Σύλλογο Χαλανδρίου ΑΡΓΩ, στο Θέατρο Ρεματιάς
# Ταυτότητα
# Όροι Χρήσης
# Διαφήμιση
# Ακολουθήστε μας!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[133], line 15
#      12 # Loop over each tag and extract the data
#      13 for tag in loc_tags:
#      14     # Retrieve the HTML document using the get() method of the requests module
# ---> 15     html_document = requests.get(tag.text)
#      17     # Create a BeautifulSoup object for parsing the HTML document
#      18     soup = BeautifulSoup(html_document.text, 'html.parser')
#
# File ~/anaconda3/envs/internship/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/envs/internship/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/internship/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/internship/lib/python3.11/site-packages/requests/sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~/anaconda3/envs/internship/lib/python3.11/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/anaconda3/envs/internship/lib/python3.11/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/anaconda3/envs/internship/lib/python3.11/site-packages/urllib3/response.py:937, in HTTPResponse.stream(self, amt, decode_content)
#     921 """
#     922 A generator wrapper for the read() method. A call will block until
#     923 ``amt`` bytes have been read from the connection or until the
#    (...)
#     934     'content-encoding' header.
#     935 """
#     936 if self.chunked and self.supports_chunked_reads():
# --> 937     yield from self.read_chunked(amt, decode_content=decode_content)
#     938 else:
#     939     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/anaconda3/envs/internship/lib/python3.11/site-packages/urllib3/response.py:1080, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1078 if self.chunk_left == 0:
#    1079     break
# -> 1080 chunk = self._handle_chunk(amt)
#    1081 decoded = self._decode(
#    1082     chunk, decode_content=decode_content, flush_decoder=False
#    1083 )
#    1084 if decoded:
#
# File ~/anaconda3/envs/internship/lib/python3.11/site-packages/urllib3/response.py:1022, in HTTPResponse._handle_chunk(self, amt)
#    1020     self.chunk_left = None
#    1021 elif self.chunk_left is not None and amt < self.chunk_left:
# -> 1022     value = self._fp._safe_read(amt)  # type: ignore[union-attr]
#    1023     self.chunk_left = self.chunk_left - amt
#    1024     returned_chunk = value
#
# File ~/anaconda3/envs/internship/lib/python3.11/http/client.py:631, in HTTPResponse._safe_read(self, amt)
#     624 def _safe_read(self, amt):
#     625     """Read the number of bytes requested.
#     626
#     627     This function should be used when <amt> bytes "should" be present for
#     628     reading. If the bytes are truly not available (due to EOF), then the
#     629     IncompleteRead exception can be used to detect the problem.
#     630     """
# --> 631     data = self.fp.read(amt)
#     632     if len(data) < amt:
#     633         raise IncompleteRead(data, amt-len(data))
#
# File ~/anaconda3/envs/internship/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/envs/internship/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/internship/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import zipfile
import os

# List of directories to be included in the zip file


# Name of the output zip file
zip_file_name = "mydirectories.zip"

# Create a new zip file and open it in write mode
with zipfile.ZipFile(zip_file_name, "w", zipfile.ZIP_DEFLATED) as zip_file:
    # Add each directory and its contents to the zip file
    for directory_name in directory_list:
        # Get the absolute path of the directory
        directory_path = os.path.abspath(directory_name)
        
        # Iterate over all the files and folders in the directory
        for root, dirs, files in os.walk(directory_path):
            for file in files:
                # Get the absolute path of each file
                file_path = os.path.join(root, file)
                
                # Add the file to the zip file using the relative path
                zip_file.write(file_path, os.path.relpath(file_path, directory_path))

print("Zip file created successfully: ", zip_file_name)
# Out:
# Zip file created successfully:  mydirectories.zip

# %% [markdown]
# ----

# %%
def extract_websites_from_sitemap(url_to_scrape):
    """
    Extracts the websites from a sitemap.xml file and saves the HTML documents in the html/ folder.
    """
    # Retrieve the sitemap.xml file
    html_document = requests.get(url_to_scrape)
    # Parse the XML document
    soup = BeautifulSoup(html_document.text, 'html.parser')
    # Find all the <loc> tags
    loc_tags = soup.find_all('loc')
    websites = []
    
    for loc_tag in loc_tags[:50]:
        # Extract the URL from the <loc> tag
        website_url = loc_tag.text
        
        # Extract the last part of the URL as the website name
        website_name = website_url.split('/')[-1]  
        
        # Save the HTML document with the website name
        response = requests.get(website_url)
        if response.status_code == 200:
            websites.append(website_name)
        else:
            print(f"Failed to retrieve HTML document for website: {website_url}")
    
    return websites


url_to_scrape = "https://myxalandri.gr/sitemap.xml"
# %%
urls = []
site_maps_file = 'sitemaps.txt'

# choice to delete or not delete the existing directories
delete_existing_directories = True


# Check if the file exists
if os.path.exists(site_maps_file):
    # Read the file and save each URL from each line to a list
    with open(site_maps_file, 'r') as f:
        urls = f.readlines()
else:
    # Warn that the file does not exist
    print('File does not exist')


for url in urls:
    # Extract the domain name and top-level domain (TLD) from the URL
    domain_dot_tld = re.search(r'(?<=https://)(.*?)(?=/)', url).group(0)

    # Check if the directory exists (directory name contains the domain name and TLD)
    if not os.path.exists(domain_dot_tld):
        print(domain_dot_tld)
        os.makedirs(domain_dot_tld)
    elif delete_existing_directories:
        print(f'Directory {domain_dot_tld} already exists. Deleting it and creating a new one')
        # Delete the directory and create a new one
        shutil.rmtree(domain_dot_tld)
        os.makedirs(domain_dot_tld)
    else:
        print(f'Directory {domain_dot_tld} already exists')
    
    # create 3 directories under the domain_dot_tld directory: html_files, txt_files,  metadata_files
    html_files = os.path.join(domain_dot_tld, 'html_files')
    txt_files = os.path.join(domain_dot_tld, 'txt_files')
    metadata_files = os.path.join(domain_dot_tld, 'metadata_files')

    # Check if the directories exist
    if not os.path.exists(html_files):
        os.makedirs(html_files)
    else: 
        print(f'Directory {html_files} already exists')

    if not os.path.exists(txt_files):
        os.makedirs(txt_files)
    else: 
        print(f'Directory {txt_files} already exists')

    if not os.path.exists(metadata_files):
        os.makedirs(metadata_files)
    else:
        print(f'Directory {metadata_files} already exists')
# Out:
# Directory myxalandri.gr already exists. Deleting it and creating a new one

# %% [markdown]
# ### Cells that extract data from urls in the sitemap (without the index pages) - accuracy optimized

# %%
def extract_websites_from_sitemap(url_to_scrape):
    """
    Extracts the websites from a sitemap.xml file and saves the HTML documents in the html/ folder.
    """
    # Retrieve the sitemap.xml file
    html_document = requests.get(url_to_scrape)
    # Parse the XML document
    soup = BeautifulSoup(html_document.text, 'html.parser')
    # Find all the <loc> tags
    loc_tags = soup.find_all('loc')
    websites = []
    
    for loc_tag in loc_tags:
        # Extract the URL from the <loc> tag
        website_url = loc_tag.text
        
        # Extract the last part of the URL as the website name
        website_name = website_url.split('/')[-1]  
        
        # Save the HTML document with the website name
        response = requests.get(website_url)
        if response.status_code == 200:
            with open(f"html/{website_name}.html", "w", encoding="utf-8") as file:
                file.write(response.text)
                websites.append(website_name)
        else:
            print(f"Failed to retrieve HTML document for website: {website_url}")
    
    return websites


url_to_scrape = "https://myxalandri.gr/sitemap.xml"
websites = extract_websites_from_sitemap(url_to_scrape)
print(websites)
# Out:
# /Users/evangeloskostakis/anaconda3/envs/internship/lib/python3.11/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
fothike-se-kolona-tis-dei-sto-xalandri', '18558-jef-maarawi-smalfeels-kai-kostas-sidirokastritis-live-spiti-bar-xalandri', '18633-asfalos-kalokairi-paidi-mono-sto-spiti-symvoules-pros-tous-goneis', '18660-o-isa-ypenthymizei-ta-proliptika-metra-gia-tin-apofygi-dysareston-synepeion-logo-kaysona', '18659-paralies-konta-stin-athina-gia-na-meineis-akomi-kai-meta-to-iliovasilema', 'penaki', '18692-to-peiratiko-tou-kapten-erntogan-geloiografia-tou-panou-iatridi', 'kairos', 'poioi-eimaste', 'oroi-xrisis', 'eidiseis?start=5', 'eidiseis?start=10', 'eidiseis?start=15', 'eidiseis?start=2055', 'athlitismos?start=4', 'athlitismos?start=8', 'athlitismos?start=12', 'athlitismos?start=472', '18500-paranomi-desmefsi-ton-athlitrion-volei-tou-gs-xalandriou-apo-ton-proedro-n-pantazi', '18649-o-apollon-xalandriou-na-kathierothei-sto-ypsilotero-podosfairika-epipedo-tis-athinas', '18501-o-nireas-xalandriou-thriamveftika-protathlitis-neon-gynaikon', '18645-f-o-t-xalandriou-stoxos-mas-i-dimiourgia-omadon-pou-tha-leitourgoyn-san-mia-kali-parea', 'politismos?start=5', 'politismos?start=10', 'politismos?start=15', 'politismos?start=530', '18386-omadiki-ekthesi-zografikis-16-kallitexnon-stin-galeri-xrysothemis-sto-xalandri', '18595-pieta-mia-mousikotheatriki-parastasi-gia-tin-apoleia-sto-theatro-rematias', '18534-oi-concordia-project-to-neaniko-sygkrotima-apo-to-xalandri-parousiazei-to-kapos-soureal', '18603-believer-antonis-vlachos-live-mia-dynamiki-mousiki-parousia-sti-rematia', '18585-mama-bampa-tha-pame-diakopes-ena-diaforetiko-kalokairi', '18262-mathimata-zois-apo-ton-koronoio-tis-psyxologou-marinas-kontzila', '18168-pos-milame-sta-paidia-gia-ton-koronoio-tis-psyxologou-marinas-kontzila', '18158-monaksia-se-synthikes-pandimias-tis-evgenias-katoyfa', '18107-efthyni-ton-dimon-pia-o-koronoios-tou-xari-kougioumtzopoulou', '18023-i-megali-apeili-einai-i-aneparkeia-tis-dimosias-dioikisis-tou-xari-kougioumtzopoulou', '17979-aftos-einai-o-dimarxos-pou-theloume-tou-paylou-kamara', '17875-anamniseis-apo-tin-paidagogo-kalliopi-moustaka-grafei-o-mathitis-tis-athanasios-xristakis', '17865-anagki-meletis-diaxeirisis-prasinou-sta-voreia-proastia-tou ...

# %%
def extract_headline_and_description(links):
    for link in links:
        html_file = 'html/' + link.split('/')[-1] + '.html'
        
        # Check if the file exists
        if not os.path.isfile(html_file):
            print(f"File {html_file} does not exist.")
            continue

        with open(html_file, "r") as file:
            html_data = file.read()

        soup = BeautifulSoup(html_data, 'html.parser')

        # Find all <script> tags with data-type="gsd"
        script_tags = soup.find_all('script', attrs={'data-type': 'gsd'})

        # Extract the headline and description from each script tag
        for script_tag in script_tags:
            # Extract the JSON data
            json_data = script_tag.string.strip()

            # Parse the JSON data
            data = json.loads(json_data)

            # Extract the headline and description using the get() method
            headline = data.get('headline')
            description = data.get('description')

            # Print the extracted values
            if headline is not None and description is not None:
                # print("Headline:", headline)
                # print("Description:", description)
                # print("------------------")
                # write to a .txt file the headline and description
                with open('txt/' + link.split('/')[-1] + '.txt', 'w') as f:
                    f.write('Title:'+ '\n' + headline + '\n')
                    f.write('Description:' + '\n' + description + '\n')
                    f.close()


extract_headline_and_description(websites)

# %%
def extract_metadata(links):
    """
    Extracts the metadata from the HTML documents of the websites to a file in JSON format.
    """
    for link in links:
        html_file = 'html/' + link + '.html'

        # Check if the file exists
        if not os.path.isfile(html_file):
            print(f"File {html_file} does not exist.")
            continue

        with open(html_file, "r") as file:
            html_data = file.read()

        soup = BeautifulSoup(html_data, 'html.parser')

        # Find all <meta> tags
        meta_tags = soup.find_all('meta')

        # Extract the desired metadata from each meta tag
        metadata = {}
        for meta_tag in meta_tags:
            name = meta_tag.get('name')
            content = meta_tag.get('content')
            if name and content:
                metadata[name] = content

        # Write the metadata to a .meta file in JSON format
        meta_file = 'meta/' + link + '.meta'
        with open(meta_file, 'w') as f:
            f.write(json.dumps(metadata, indent=4, ensure_ascii=False))

extract_metadata(websites)

# %% [markdown]
# ### Cells that extract data from urls in the sitemap (without the index pages) - storage optimized

# %%
def extract_href_from_html_files(file_list):
    href_list_all = []
    i = 0
    for file_path in file_list:

        # Here we will store all the hrefs
        href_list = []
        href_list_xal = []
        href_list_other = []

        if os.path.isfile('html/' + file_path + '.html'):
            with open('html/' + file_path + '.html' , 'r') as file:
                # Read the file content
                content = file.read()
                # Create a BeautifulSoup object for parsing the HTML document
                soup = BeautifulSoup(content, 'html.parser')
                # Find all <a> tags
                href_tags = soup.find_all('a')
                for tag in href_tags:
                    # Extract the href attribute from the <a> tag
                    href = tag.get('href')
                    # Append the href to the list of hrefs
                    href_list_all.append(href)
                    if href:
                        href_list.append(href)
                        if 'myxalandri' in href:
                            href_list_xal.append(href)
                        else: 
                            href_list_other.append(href)

            # Print the number of hrefs
            print(file_path+":\t"+ "total\t" +str(len(href_list)))
            print(file_path+":\t"+ "xalandri\t" +str(len(href_list_xal)))
            print(file_path+":\t"+ "other\t" +str(len(href_list_other)))
            if len(href_list_other) > 50:
                print(file_path+":\t"+ "is index page")
                i += 1

            print("--------------------------------------------------"*2)
        else:
            print(f"File not found: {file_path}")
    print(i)
    return href_list_all


hrefs = extract_href_from_html_files(websites)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 46
#      42     print(i)
#      43     return href_list_all
# ---> 46 hrefs = extract_href_from_html_files(websites)
#
# NameError: name 'websites' is not defined

# %%
def extract_headline_and_description(links):
    for link in links:
        
        html_link = 'https://myxalandri.gr/' + link 
        
        html_document = requests.get(html_link)
        soup = BeautifulSoup(html_document, 'html.parser')

        # Find all <script> tags with data-type="gsd"
        script_tags = soup.find_all('script', attrs={'data-type': 'gsd'})

        # Extract the headline and description from each script tag
        for script_tag in script_tags:
            # Extract the JSON data
            json_data = script_tag.string.strip()

            # Parse the JSON data
            data = json.loads(json_data)

            # Extract the headline and description using the get() method
            headline = data.get('headline')
            description = data.get('description')

            # Print the extracted values
            if headline is not None and description is not None:
                # print("Headline:", headline)
                # print("Description:", description)
                # print("------------------")
                # write to a .txt file the headline and description
                with open('txt/' + link + '.txt', 'w') as f:
                    f.write('Title:'+ '\n' + headline + '\n')
                    f.write('Description:' + '\n' + description + '\n')
                    f.close()

extract_headline_and_description(websites)

# %%
def extract_websites_from_sitemap(url_to_scrape):
    """
    Extracts the websites from the sitemap of the given URL (urls that don't contain index pages).
    """
    # Retrieve the HTML document of the sitemap
    html_document = requests.get(url_to_scrape)
    html_document.encoding = 'utf-8'

    # Create a BeautifulSoup object for parsing the HTML document
    soup = BeautifulSoup(html_document.text, 'html.parser')

    # Find all <loc> tags in the sitemap
    loc_tags = soup.find_all('loc')
    websites = []
    
    i = 0
    
    # Extract the website from each <loc> tag
    for loc_tag in loc_tags:
        
        href_list_other = []

        website_url = loc_tag.text

        # Retrieve the HTML document of the website
        response = requests.get(website_url)

        # Create a BeautifulSoup object for parsing the HTML document
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find all <a> tags
        href_tags = soup.find_all('a')
        
        for tag in href_tags:
            # Extract the href attribute from the <a> tag
            href = tag.get('href')
            if href and 'myxalandri' not in href: 
                href_list_other.append(href) 
                        
        # Print the number of hrefs and if the website is an index 
        if len(href_list_other) > 50:
            print(website_url+":\t"+ "is index page")
            print("--------------------------------------------------"*2)
            i += 1
        elif len(href_list_other) <= 50 and response.status_code == 200:
            # Write the HTML document to a .html file
            with open('html/' + website_url.split('/')[-1] + '.html', 'w') as f:
                f.write(response.text)
                f.close()
            # Append the website to the list of websites
            websites.append(website_url)

    print(i)
    return websites


url_to_scrape = "https://myxalandri.gr/sitemap.xml"
websites = extract_websites_from_sitemap(url_to_scrape)
# Out:
# /Users/evangeloskostakis/anaconda3/envs/internship/lib/python3.11/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# https://myxalandri.gr/:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/apopseis:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/penaki:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=5:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=10:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=15:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=2055:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=4:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=8:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=12:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=472:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=5:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=10:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=15:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=530:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/apopseis?start=10:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/apopseis?start=20:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/apopseis?start=30:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/apopseis?start=40:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=5:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=10:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=15:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=100:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=6:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=12:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=18:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=174:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/penaki?start=5:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/penaki?start=10:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/penaki?start=15:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/penaki?start=55:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=20:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=25:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=30:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=2050:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=2040:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=2045:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=16:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=20:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=24:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=468:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=460:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=464:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=20:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=25:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=30:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=525:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=515:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=520:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=20:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri/17938-xalandri-poy-tha-fas-kala-kai-poy-tha-diaskedaseis-stin-pio-agapimeni-perioxi-ton-voreion-proastion:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=25:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=30:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=95:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=85:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=90:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=24:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=30:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=36:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=168:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=156:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=162:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/penaki?start=20:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/penaki?start=25:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/penaki?start=30:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/penaki?start=50:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/penaki?start=40:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/penaki?start=45:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=35:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=40:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=45:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=2035:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=2025:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=2030:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=28:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=32:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=36:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=456:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=448:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/athlitismos?start=452:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=35:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=40:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=45:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=510:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=500:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/politismos?start=505:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=35:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=40:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=45:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=80:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/out-xalandri?start=75:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=42:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=48:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=54:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=150:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=138:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/mymag?start=144:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/penaki?start=35:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=50:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=55:	is index page
# ----------------------------------------------------------------------------------------------------
# https://myxalandri.gr/eidiseis?start=60:	is index page
# ----------------------------------------------------------------------------------------------------
# 106

# %%
def save_html_files(websites):
    """
    Saves the HTML files of the given websites.
    """
    for website in websites:
        # Retrieve the HTML document of the website
        response = requests.get(website)
        response.encoding = 'utf-8'

        # Write the HTML document to a .html file
        with open('html/' + website.split('/')[-1] + '.html', 'w') as f:
            f.write(response.text)
            f.close()

save_html_files(websites)

# %%
import requests
from bs4 import BeautifulSoup

def extract_websites_from_sitemap(url_to_scrape):
    """
    Extracts the websites from the sitemap of the given URL (urls that don't contain index pages).
    """
    # Retrieve the HTML document of the sitemap
    html_document = requests.get(url_to_scrape)
    html_document.encoding = 'utf-8'

    # Create a BeautifulSoup object for parsing the HTML document
    soup = BeautifulSoup(html_document.text, 'html.parser')

    # Find all <loc> tags in the sitemap
    loc_tags = soup.find_all('loc')
    websites = []
    index_count = 0

    # Extract the website from each <loc> tag
    for loc_tag in loc_tags:
        website_url = loc_tag.text

        # Retrieve the HTML document of the website
        response = requests.get(website_url)

        # Create a BeautifulSoup object for parsing the HTML document
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all <a> tags
        href_tags = soup.find_all('a')
        href_list_other = []

        for tag in href_tags:
            # Extract the href attribute from the <a> tag
            href = tag.get('href')
            if href and 'myxalandri' not in href:
                href_list_other.append(href)

        # Print the number of hrefs and if the website is an index
        if len(href_list_other) > 50:
            # print(len(href_list_other))
            # print(website_url + ":\t" + "is an index page")
            # print("--------------------------------------------------" * 2)
            index_count += 1
        elif len(href_list_other) <= 50 and response.status_code == 200:
            # Write the HTML document to a .html file
            with open('html/' + website_url.split('/')[-1] + '.html', 'w') as f:
                f.write(response.text)

            # Append the website to the list of websites
            websites.append(website_url)

    print(index_count)
    return websites


url_to_scrape = "https://myxalandri.gr/sitemap.xml"
websites = extract_websites_from_sitemap(url_to_scrape)
# Out:
# 106

# %%
print(websites)
# Out:
# ['https://myxalandri.gr/politismos/18694-to-neo-orario-kai-o-tropos-leitourgias-ton-dimotikon-vivliothikon-xalandriou', 'https://myxalandri.gr/eidiseis/18688-kalosorisma-tis-enosis-goneon-xalandriou-gia-ti-nea-sxoliki-xronia', 'https://myxalandri.gr/eidiseis/18691-me-156-687-88-epixorigeitai-o-dimos-xalandriou-gia-pliromi-misthomaton-sxolikon-monadon', 'https://myxalandri.gr/eidiseis/18693-fotia-se-aporrimmatoforo-tou-dimou-xalandriou-pos-proklithike', 'https://myxalandri.gr/eidiseis/18690-synelifthi-sto-xalandri-50xronos-allodapos-gia-tilefonikes-apates-me-to-prosxima-troxaiou-atyximatos', 'https://myxalandri.gr/athlitismos/18689-xalandri-orizontas-2023-o-athlitismos-exei-koinoniko-prosimo-kai-einai-to-xamogelo-kathe-topikis-koinonias', 'https://myxalandri.gr/eidiseis/18687-dimos-xalandriou-nea-sxoliki-xronia-se-kainoyrgia-sxoleia', 'https://myxalandri.gr/eidiseis/18686-i-eggrafi-apantisi-tou-deddie-gia-ti-revmatoklopi-ston-katavlismo-roma-tou-nomismatokopeiou', 'https://myxalandri.gr/politismos/18683-ksekinoyn-teli-septemvriou-mathimata-sto-ergastirio-mousikis-ekpaidefsis-dimou-xalandriou', 'https://myxalandri.gr/eidiseis/18685-a-g-elme-v-athinas-anoixto-kalesma-se-goneis-kai-ekpaideftikoys-gia-to-anoigma-ton-sxoleion', 'https://myxalandri.gr/eidiseis/18684-2o-ergastirio-symmetoxikoy-sxediasmoy-gia-ti-sofokli-venizelou-sto-kato-xalandri', 'https://myxaland