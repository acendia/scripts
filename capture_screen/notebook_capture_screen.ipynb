# %% [markdown]
# # Capture Display

# %% [markdown]
# **Author**: Evangelos Kostakis
#
# **Email**: it21945@hua.gr
#
# **Date**: 2023-07-04
#
# **Description**: Script to capture the screen using mss

# %% [markdown]
# Personal Requirements:
# 1. Use the conda environment called "top" on macbook

# %% [markdown]
# ### Install dependencies

# %%
# install cv2
! pip install opencv-python
# install pyautogui
! pip install pyautogui
# install python-xlib (you might not need this, idk)
! pip install python-xlib

### for linux ###
# install scrot (run on terminal, because it asks for password) 
# ! sudo apt-get install scrot
# Out:
# Requirement already satisfied: opencv-python in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.21.2 in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from opencv-python) (1.25.1)
# Requirement already satisfied: pyautogui in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (0.9.54)
# Requirement already satisfied: pymsgbox in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyautogui) (1.0.7)
# Requirement already satisfied: pyscreeze>=0.1.21 in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyautogui) (0.1.29)
# Requirement already satisfied: pygetwindow>=0.0.5 in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyobjc-core in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyautogui) (9.2)
# Requirement already satisfied: pyobjc-framework-quartz in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyautogui) (9.2)
# Requirement already satisfied: pyrect in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyscreenshot in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyscreeze>=0.1.21->pyautogui) (3.1)
# Requirement already satisfied: Pillow>=9.3.0 in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyscreeze>=0.1.21->pyautogui) (10.0.0)
# Requirement already satisfied: pyperclip in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from mouseinfo->pyautogui) (1.8.2)
# Requirement already satisfied: rubicon-objc in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from mouseinfo->pyautogui) (0.4.6)
# Requirement already satisfied: pyobjc-framework-Cocoa>=9.2 in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyobjc-framework-quartz->pyautogui) (9.2)
# Requirement already satisfied: EasyProcess in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: entrypoint2 in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: mss in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (9.0.1)
# Requirement already satisfied: python-xlib in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (0.33)
# Requirement already satisfied: six>=1.10.0 in /Users/evangeloskostakis/anaconda3/envs/top/lib/python3.11/site-packages (from python-xlib) (1.16.0)

# %% [markdown]
# ### Import packages

# %%
import cv2
import numpy as np
from mss import mss
from PIL import Image
import pyautogui
import time

# %% [markdown]
# ### Capture Screen

# %%
# get size of screen 
screen_size = pyautogui.size()

# change the choice to "default" or "optimized", based on your needs.
choice = "optimized"

if choice == "default":
        bounding_box = {'top': 0, 'left': 0, 'width': screen_size.width, 'height': screen_size.height}
elif choice == "optimized":
    bounding_box = {'top': 0, 'left': 0, 'width': 500, 'height': 500}

# mss is a library that takes screenshots
sct = mss()

# Start time
start_time = time.time()
frame_count = 0

# loop to take screenshots and display them
while True:
    # take screenshot of the bounding box
    sct_img = sct.grab(bounding_box)
    
    # convert the image to numpy array and display it
    cv2.imshow('screen', np.array(sct_img))

    # Check if user wants to quit
    if (cv2.waitKey(1) & 0xFF) == ord('q'):
        cv2.destroyAllWindows()
        break

    # Check if user clicked to close window (doesn't work on macos, maybe on linux. Try it out)
    if cv2.getWindowProperty('screen', cv2.WND_PROP_VISIBLE) < 1:
        cv2.destroyAllWindows()
        break

    # Calculate frames per second (fps)
    elapsed_time = time.time() - start_time
    fps = frame_count / elapsed_time
    # print("fps: " + str(fps))
    print(f"fps: {fps:.2f}")
    frame_count += 1


# Calculate the total time taken
end_time = time.time()
total_time = end_time - start_time

print(f"Total time taken: {total_time:.2f} seconds")
# Out:
# fps: 0.00
# fps: 2.43
# fps: 4.26
# fps: 5.69
# fps: 6.85
# fps: 7.85
# fps: 8.35
# fps: 9.13
# fps: 9.82
# fps: 10.27
# fps: 10.73
# fps: 11.21
# fps: 11.65
# fps: 12.00
# fps: 12.21
# fps: 12.51
# fps: 12.78
# fps: 13.05
# fps: 13.20
# fps: 13.41
# fps: 13.64
# fps: 13.83
# fps: 13.96
# fps: 14.16
# fps: 14.35
# fps: 14.50
# fps: 14.50
# fps: 14.60
# fps: 14.74
# fps: 14.84
# fps: 14.87
# fps: 14.99
# fps: 15.09
# fps: 15.10
# fps: 15.03
# fps: 15.06
# fps: 15.13
# fps: 15.15
# fps: 15.17
# fps: 15.22
# fps: 15.21
# fps: 15.19
# fps: 15.22
# fps: 15.27
# fps: 15.32
# fps: 15.35
# fps: 15.35
# fps: 15.36
# fps: 15.38
# fps: 15.42
# fps: 15.47
# fps: 15.51
# fps: 15.57
# fps: 15.62
# fps: 15.67
# fps: 15.70
# fps: 15.75
# fps: 15.81
# fps: 15.85
# fps: 15.90
# fps: 15.94
# fps: 15.97
# fps: 16.02
# fps: 16.06
# fps: 16.10
# fps: 16.14
# fps: 16.18
# fps: 16.20
# fps: 16.24
# fps: 16.27
# fps: 16.31
# fps: 16.35
# fps: 16.38
# fps: 16.42
# fps: 13.87
# fps: 13.92
# fps: 13.98
# fps: 14.03
# fps: 14.08
# fps: 14.13
# fps: 14.18
# fps: 14.23
# fps: 14.28
# fps: 14.33
# fps: 14.37
# fps: 14.41
# fps: 14.45
# fps: 14.49
# fps: 14.54
# fps: 14.58
# fps: 14.62
# fps: 14.65
# fps: 14.69
# fps: 14.73
# fps: 14.77
# fps: 14.80
# fps: 14.84
# fps: 14.88
# fps: 14.92
# fps: 14.95
# fps: 14.99
# fps: 15.02
# fps: 15.07
# fps: 15.10
# fps: 15.14
# fps: 15.17
# fps: 15.21
# fps: 15.20
# fps: 15.21
# fps: 15.23
# fps: 15.26
# fps: 15.28
# fps: 15.31
# fps: 15.33
# fps: 15.36
# fps: 15.37
# fps: 15.38
# fps: 15.41
# fps: 15.44
# fps: 15.47
# fps: 15.49
# fps: 15.50
# fps: 15.53
# fps: 15.55
# fps: 15.58
# fps: 15.61
# fps: 15.64
# fps: 15.66
# fps: 15.69
# fps: 15.72
# fps: 15.74
# fps: 15.76
# fps: 15.78
# fps: 15.80
# fps: 15.82
# fps: 15.85
# fps: 15.87
# fps: 15.89
# fps: 15.91
# fps: 15.93
# fps: 15.95
# fps: 15.98
# fps: 16.00
# fps: 16.02
# fps: 16.04
# fps: 16.06
# fps: 16.07
# fps: 16.09
# fps: 16.11
# fps: 16.13
# fps: 16.15
# fps: 16.17
# fps: 16.19
# fps: 16.21
# fps: 16.22
# fps: 16.24
# fps: 16.26
# fps: 16.28
# fps: 16.30
# fps: 16.31
# fps: 16.33
# fps: 16.34
# fps: 16.36
# fps: 16.37
# fps: 16.39
# fps: 16.41
# fps: 16.43
# fps: 16.44
# fps: 16.46
# fps: 16.48
# fps: 16.49
# fps: 16.51
# fps: 16.53
# fps: 16.54
# fps: 16.56
# fps: 16.58
# fps: 16.59
# fps: 16.61
# fps: 16.63
# fps: 16.64
# fps: 16.66
# fps: 16.67
# fps: 16.69
# fps: 16.70
# fps: 16.71
# fps: 16.73
# fps: 16.74
# fps: 16.76
# fps: 16.77
# fps: 16.79
# fps: 16.80
# fps: 16.82
# fps: 16.83
# fps: 16.84
# fps: 16.86
# fps: 16.87
# fps: 16.88
# fps: 16.89
# fps: 16.90
# fps: 16.91
# fps: 16.92
# fps: 16.93
# fps: 16.95
# fps: 16.96
# fps: 16.97
# fps: 16.98
# fps: 16.99
# fps: 17.00
# fps: 17.01
# fps: 17.01
# fps: 17.03
# fps: 17.04
# fps: 17.05
# fps: 17.06
# fps: 17.07
# fps: 17.08
# fps: 17.09
# fps: 17.10
# fps: 17.11
# fps: 17.13
# fps: 17.14
# fps: 17.14
# fps: 17.16
# fps: 17.17
# fps: 17.18
# fps: 17.19
# fps: 17.20
# fps: 17.21
# fps: 17.22
# fps: 17.23
# fps: 17.24
# fps: 17.25
# fps: 17.26
# fps: 17.27
# fps: 17.28
# Total time taken: 13.59 seconds

# %% [markdown]
# **Notes**
# - **The python script performs much better (around 30 fps)**
# - The python script contains a slightly different code for the sake of customization
# - The bigger the bounding box the fewer the frames (needs a lot of processing power).
# - It is better to create a relatively smaller bounding box (to the monitor resolution).
# - There is problem with the opencv window when quitting

# %% [markdown]
# ### I hope that it was helpful!
